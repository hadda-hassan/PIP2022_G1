# %% [markdown]
# # ACP on cleaned dataset

# %%
#Import
import pandas as pd
import numpy as np

#LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
#Importing complet data
data1 = pd.read_csv('C:/Users/noree/OneDrive/Documents/Mes documents/M1 SID/Interpromo/PIP_2022NA/DATA1/DATA1/DONNEES_CONCAT_TLSE-LD/DATA1_COMPLET.csv')
data1
# Out:
# C:\Users\noree\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                  ID  TOP_FRAUDE  TOP_FRAUDE_CARTE  \
# 0       8312v5IodTRgOR8/FWWjGEwsg==           0                 0
# 1       831pI3Dnm1zz6NG0iCJTfcilQ==           0                 0
# 2       831b9S86qzWBJCaqgYOVPwWMQ==           0                 0
# 3       831tT9jw5y/rwwLEMZF7PyE8w==           0                 0
# 4       8317VwmuKeVaijtrz0cTWOm4A==           0                 0
# ...                             ...         ...               ...
# 849341  835mBEOByTBamgQVgQg771KDA==           1                 1
# 849342  835rWBxack6OQY9AQFqyqJd5g==           1                 1
# 849343  835F1MFghZuFjdn+sBHNuQaBw==           1                 1
# ...

# %%
#Importing cleaned data
data2 = pd.read_csv('C:/Users/noree/OneDrive/Documents/Mes documents/M1 SID/Interpromo/PIP_2022NA/crypted_DATA1/Donnees_v2.csv')
data2
# Out:
#         Unnamed: 0                           ID  TOP_FRAUDE  TOP_FRAUDE_CARTE  \
# 0                0  8312v5IodTRgOR8/FWWjGEwsg==           0                 0
# 1                1  831pI3Dnm1zz6NG0iCJTfcilQ==           0                 0
# 2                2  831b9S86qzWBJCaqgYOVPwWMQ==           0                 0
# 3                3  831tT9jw5y/rwwLEMZF7PyE8w==           0                 0
# 4                4  8317VwmuKeVaijtrz0cTWOm4A==           0                 0
# ...            ...                          ...         ...               ...
# 849407      849407  835mBEOByTBamgQVgQg771KDA==           1                 1
# 849408      849408  835rWBxack6OQY9AQFqyqJd5g==           1                 1
# 849409      849409  835F1MFghZuFjdn+sBHNuQaBw==           1                 1
# 849410      849410  835HAiChYU6Al85Ed4c5I/urw==           1                 1
# 849411      849411  835g8FUcHQCK+Bn93a9y9Ko7w==           1                 0
#
# ...

# %%
df = data2.copy()
df.head()
# Out:
#    Unnamed: 0                           ID  TOP_FRAUDE  TOP_FRAUDE_CARTE  \
# 0           0  8312v5IodTRgOR8/FWWjGEwsg==           0                 0
# 1           1  831pI3Dnm1zz6NG0iCJTfcilQ==           0                 0
# 2           2  831b9S86qzWBJCaqgYOVPwWMQ==           0                 0
# 3           3  831tT9jw5y/rwwLEMZF7PyE8w==           0                 0
# 4           4  8317VwmuKeVaijtrz0cTWOm4A==           0                 0
#
#    TOP_FRAUDE_VIREMENT  TOP_E_RELEVE  MESSAGERIE_WEB_ACTIVE  \
# 0                    0           0.0                    0.0
# 1                    0           1.0                    1.0
# 2                    0           1.0                    1.0
# 3                    0           1.0                    1.0
# 4                    0           1.0                    1.0
#
#    FIAB_TEL_DOMICILE  FIAB_TEL_TRAVAIL  FIAB_TEL_PORTABLE  ...  \
# 0                0.0               0.0                1.0  ...
# ...

# %% [markdown]
# ## ACP (LDA) on samples

# %%
ech_test = df.sample(int(len(df) * 0.10), random_state=1)
ech_train = df.drop(ech_test.index)

# %%
object_columns = df.select_dtypes(include=['object']).columns
object_columns
# Out:
# Index(['ID'], dtype='object')

# %%
X_test = ech_test.iloc[:,3:]
Y_test = ech_test.iloc[:,2]

# %%
clf = LDA()
clf.fit(X_test, Y_test)
# Out:
# LinearDiscriminantAnalysis()

# %% [markdown]
# ## Columns with more than 10 modalities (quantitative variables)

# %%
#var_quant : quantitative variables with more than 10 modalities
var_quant = []
for col in data1 :
    if (data1[col].nunique() > 10) and (str(data1[col].dtypes) == 'float64' or str(data1[col].dtypes) == 'int64') and (col != 'csp_1' and col != 'csp_2'):
        print(col, " ", str(data1[col].dtypes), " ", str(data1[col].nunique()))
        var_quant.append(col)
print(len(var_quant))
# Out:
# NBJ_CNT_AGENCE_DEPOT_6M   float64   69
# NBJ_CNT_AGENCE_VENTE_6M   float64   11
# NBJ_CNT_RDV_AGENCE_6M   float64   15
# NBJ_CNT_AUTOMATE_RETRAIT_6M   float64   164
# NBJ_CNT_AUTOMATES_DEPOT_6M   float64   63
# NBJ_CNT_AGENCE_RETRAIT_6M   float64   41
# NBJ_CNT_AGENCE_6M   float64   79
# NBJ_CNT_SMS_6M   float64   156
# NBJ_CNT_EMAIL_6M   float64   125
# NBJ_CNT_APPELENTRANTS_6M   float64   14
# NBJ_CNT_AUTOMATE_6M   float64   178
# TOT_CNX_WEB_WEEK_6M   float64   573
# TOT_CNX_WEB_END_6M   float64   266
# TOT_CCOMPTE_WEB_6M   float64   393
# TOT_IMPRESSIONRIB_WEB_6M   float64   234
# TOT_TLCHGMTEDOC_WEB_6M   float64   99
# TOT_CCOMPTE_MBANQUE_6M   float64   253
# TOT_CMS_WEB_6M   float64   20
# TOT_ATT_SIGN_VAD_WEB_6M   float64   11
# TOT_CHABITAT_WEB_6M   float64   38
# TOT_MODIF_PARAM_CARTE_WEB_6M   float64   154
# TOT_CNX_INVSTORE_WEB_6M   float64   236
# NB_JR_WEB_6M   float64   185
# NB_CNXS_WEB_6M   float64   737
# NB_JR_MBANQUE_6M   float64   185
# ...
