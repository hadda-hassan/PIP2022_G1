# %%
# from google.colab import drive
# import tensorflow as tf
# multi headed multi-step cnn 
# !pip install tensorflow
# !pip install tensorflow_addons
import pandas as pd
import numpy as np
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from math import sqrt
from numpy import split
from numpy import array
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
from keras.utils.vis_utils import plot_model
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D, Conv2D, MaxPooling1D
from keras.layers.convolutional import MaxPooling1D
from keras.models import Model
from keras.layers import Input
from keras.layers.merge import concatenate
from keras import optimizers, metrics
from sklearn.preprocessing import MinMaxScaler
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from tensorflow import random as rnd
import keras
from tensorflow.python.ops import math_ops
from keras import backend as K
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import tempfile
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import tensorflow_addons as tfa

import os

import tensorflow as tf
from tensorflow import keras

from sklearn.model_selection import train_test_split
# import NN layers and other componenets.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Dropout
from tensorflow.keras import optimizers
import matplotlib.pyplot as plt # for plotting data and creating different charts.
import numpy as np # for math and arrays
import pandas as pd # data from for the data.
import seaborn as sns # for plotting.

print(f"Tensorflow version: {tf.version.VERSION}")
# Out:
# Tensorflow version: 2.7.0

# %%
tf.random.set_seed(13) # to make sure the experiment is reproducible.
tf.debugging.set_log_device_placement(False)

# %%
# # y_train.shape
# from pytorch_widedeep.metrics import FBetaScore
# from pytorch_widedeep.metrics import F1Score
# fbeta = FBetaScore(beta=2)
# f1=F1Score()

# %%
X=pd.read_csv('/home/sid2020-7/Bureau/DATA1/X_data_nearmiss_0.01.csv')
print(tf.version.VERSION)
y=pd.read_csv('/home/sid2020-7/Bureau/DATA1/Y_data_nearmiss_0.01.csv')
y.drop('Unnamed: 0',inplace=True,axis=1)
X.drop('Unnamed: 0',inplace=True,axis=1)
# print(len(data_B.columns))
# L=list(data_B.columns)
# L.remove('TOP_FRAUDE')
# X= data_B[L]
# y= data_B.TOP_FRAUDE
# # X.values
y
# Out:
# 2.7.0
#         TOP_FRAUDE
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 164625           1
# 164626           1
# 164627           1
# 164628           1
# 164629           1
#
# [164630 rows x 1 columns]

# %%
trainX, tempX, trainy, tempy = train_test_split(X, y, test_size=0.4, random_state=2,stratify=y)
testX, tvalX, testy, tvaly = train_test_split(tempX, tempy, test_size=0.5, random_state=2,stratify=tempy)
trainX.shape
# Out:
# (98778, 61)

# %%
# !pip3 install --upgrade pip
# !pip3 install tfa-nightly
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 2.2 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.1.1
#     Uninstalling pip-20.1.1:
#       Successfully uninstalled pip-20.1.1
# ...
#      |████████████████████████████████| 1.1 MB 2.7 MB/s
# ...

# %%
# ##  Metrics

# Fbeta_loss_function = tf.metrics.FBetaScore(
#     num_classes=2,
#     average: Optional[str] = None,
#     beta: tfa.types.FloatTensorLike = 1.0,
#     threshold: Optional[FloatTensorLike] = None,
#     name: str = 'fbeta_score',
#     dtype: tfa.types.AcceptableDTypes = None,
#     **kwargs)

Fbeta_loss_function=tfa.metrics.FBetaScore(num_classes=2,average="micro",threshold=0.5)

METRICS = [
#       keras.metrics.TruePositives(name='tp'),
#       keras.metrics.FalsePositives(name='fp'),
#       keras.metrics.TrueNegatives(name='tn'),
#       keras.metrics.FalseNegatives(name='fn'), 
#       keras.metrics.BinaryAccuracy(name='accuracy'),
#       keras.metrics.Precision(name='precision'),
#       keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'),
    Fbeta_loss_function,# precision-recall curve
]

# %%
trainX.shape[1]
# Out:
# 61

# %%
# We decalred a function for creating a model.
def build_model2_three_hidden_layers(metrics=METRICS):
    # Keras model object created from Sequential class. This will be the container that contains all layers.
    model = Sequential()

    # The model so far is empty. It can be constructed by adding layers and compilation.
    # This Keras model with multiple hidden layers.
    
    # Input Layer with 32 Neurons
    model.add(Dense(32, input_shape = (trainX.shape[1],)))    # Input layer => input_shape must be explicitly designated
#     model.add(Activation('relu')) # relu or sigmoid.
    
    model.add(Dense(32,Activation('relu')))                         # Hidden layer 1 => only output dimension should be designated (output dimension = # of Neurons = 32)
    
    
#     model.add(Dense(64, Activation('relu')))                         # Hidden layer 2 => only output dimension should be designated (output dimension = # of Neurons = 64)
    
    
#     model.add(Dense(128, Activation('relu')))                         # Hidden layer 3 => only output dimension should be designated (output dimension = # of Neurons = 128)

    
    model.add(Dense(1))                          # Output layer => output dimension = 1 since it is a regression problem
    
    # Activation: sigmoid, softmax, tanh, relu, LeakyReLU. 
    #Optimizer: SGD, Adam, RMSProp, etc. # https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
    learning_rate = 0.001
    optimizer = optimizers.SGD(learning_rate)
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                optimizer=optimizer,
                metrics=METRICS) 
    return model

model2 = build_model2_three_hidden_layers()
print('Here is a summary of this model: ')
model2.summary()
# Out:
# Here is a summary of this model:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_27 (Dense)            (None, 32)                1984
#
#  dense_28 (Dense)            (None, 32)                1056
#
#  dense_29 (Dense)            (None, 1)                 33
#
# ...
# Total params: 3,073
# Trainable params: 3,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
EPOCHS = 100
batch_size = 16 # 6 iteration

model = build_model2_three_hidden_layers(metrics=METRICS)
print('Here is a summary of this model: ')
model.summary()

model.fit(trainX, trainy,
        batch_size = batch_size,
        epochs=EPOCHS, 
        verbose=1,
        shuffle=True,
        steps_per_epoch = int(trainX.shape[0] / batch_size) ,
        validation_data = (tvalX, tvaly),   
    )
# Out:
# Here is a summary of this model:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_30 (Dense)            (None, 32)                1984
#
#  dense_31 (Dense)            (None, 32)                1056
#
#  dense_32 (Dense)            (None, 1)                 33
#
# ...
# Total params: 3,073
# Trainable params: 3,073
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ...

# %%
# %%time

# We decalred a function for creating a model.
def build_model1_two_hidden_layers():
    # Keras model object created from Sequential class. This will be the container that contains all layers.
    model = Sequential()

    # The model so far is empty. It can be constructed by adding layers and compilation.
    # This Keras model with multiple hidden layers.
    
    # Input Layer with 10 Neurons
    model.add(Dense(32, input_shape = (trainX.shape[1],)))    # Input layer => input_shape must be explicitly designated
#     model.add(Activation('relu')) # relu or sigmoid.
    
#     model.add(Dense(128,Activation('relu')))                         # Hidden layer 1 => only output dimension should be designated (output dimension = # of Neurons = 50)
    
    
    
    
    model.add(Dense(1))                          # Output layer => output dimension = 1 since it is a regression problem
    
    # Activation: sigmoid, softmax, tanh, relu, LeakyReLU. 
    #Optimizer: SGD, Adam, RMSProp, etc. # https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
    learning_rate = 0.0001
    optimizer = optimizers.SGD(learning_rate)
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                optimizer=optimizer,
                metrics=METRICS) # for regression problems, mean squared error (MSE) is often employed
    return model


EPOCHS = 100
batch_size = 16 # 6 iteration

# model = build_model1_two_hidden_layers()
print('Here is a summary of this model: ')
model.summary()


# with tf.device('/CPU:0'): # it can be with '/CPU:0'
# with tf.device('/GPU:0'): # comment the previous line and uncomment this line to train with a GPU, if available.
model.fit(trainX, trainy,
        batch_size = batch_size,
        epochs=EPOCHS, 
        verbose=1,
        shuffle=True,
        steps_per_epoch = int(trainX.shape[0] / batch_size) ,
        validation_data = (tvalX, tvaly),   
    )
# Out:
# Here is a summary of this model:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 32)                1984
#
#  dense_10 (Dense)            (None, 1)                 33
#
# ...
# Total params: 2,017
# Trainable params: 2,017
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
# ...

# %% [markdown]
# ## 2 parie

# %%
# ## exemple data
# file = tf.keras.utils
raw_df = pd.read_csv('/home/sid2020-7/Téléchargements/creditcard.csv')
raw_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
raw_df[['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V26', 'V27', 'V28', 'Amount', 'Class']].describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean  -1.552563e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# ...

# %%
cleaned_df =data_B.copy()

# # You don't want the `Time` column.
# cleaned_df.pop('Time')

# # The `Amount` column covers a huge range. Convert to log-space.
# eps = 0.001 # 0 => 0.1¢
# cleaned_df['Log Ammount'] = np.log(cleaned_df.pop('Amount')+eps)

# %%
# 63 Use a utility from sklearn to split and shuffle your dataset.
train_df, test_df = train_test_split(cleaned_df, test_size=0.2,stratify=cleaned_df['TOP_FRAUDE'])
train_df, val_df = train_test_split(train_df, test_size=0.2,stratify=train_df['TOP_FRAUDE'])

# Form np arrays of labels and features.
train_labels = np.array(train_df.pop('TOP_FRAUDE'))
bool_train_labels = train_labels != 0
val_labels = np.array(val_df.pop('TOP_FRAUDE'))
test_labels = np.array(test_df.pop('TOP_FRAUDE'))

train_features = np.array(train_df)
val_features = np.array(val_df)
test_features = np.array(test_df)

scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)

val_features = scaler.transform(val_features)
test_features = scaler.transform(test_features)


test_features
print('Training labels shape:', train_labels.shape)
print('Validation labels shape:', val_labels.shape)
print('Test labels shape:', test_labels.shape)

print('Training features shape:', train_features.shape)
print('Validation features shape:', val_features.shape)
print('Test features shape:', test_features.shape)
# Out:
# Training labels shape: (543623,)
# Validation labels shape: (135906,)
# Test labels shape: (169883,)
# Training features shape: (543623, 61)
# Validation features shape: (135906, 61)
# Test features shape: (169883, 61)

# %%
train_features
# Out:
# array([[-0.98987326,  0.71922138, -0.30748871, ...,  1.1248571 ,
#         -0.48318608, -0.55872492],
#        [ 1.01023034,  0.71922138, -0.30748871, ...,  1.1248571 ,
#         -0.48318608,  1.7897895 ],
#        [ 1.01023034,  0.71922138, -0.30748871, ..., -0.88900182,
#         -0.48318608, -0.55872492],
#        ...,
#        [-0.98987326,  0.71922138, -0.30748871, ..., -0.88900182,
#          2.06959603, -0.55872492],
#        [ 1.01023034,  0.71922138, -0.30748871, ..., -0.88900182,
#         -0.48318608, -0.55872492],
#        [ 1.01023034,  0.71922138, -0.30748871, ...,  1.1248571 ,
#         -0.48318608, -0.55872492]])

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# pos_df = pd.DataFrame(train_features[ bool_train_labels], columns=train_df.columns)
# neg_df = pd.DataFrame(train_features[~bool_train_labels], columns=train_df.columns)

# sns.jointplot(pos_df['V5'], pos_df['V6'],
#               kind='hex', xlim=(-5,5), ylim=(-5,5))
# plt.suptitle("Positive distribution")

# sns.jointplot(neg_df['V5'], neg_df['V6'],
#               kind='hex', xlim=(-5,5), ylim=(-5,5))
# _ = plt.suptitle("Negative distribution")

# %%
from sklearn.metrics import fbeta_score
def make_model(metrics=METRICS, output_bias=None):
  if output_bias is not None:
    output_bias = tf.keras.initializers.Constant(output_bias)
  model = keras.Sequential([
      keras.layers.Dense(
          16, activation='relu',
          input_shape=(train_features.shape[-1],)),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
  ])

  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=METRICS)
# tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  return model

# %%
model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                992
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# ...
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
BATCH_SIZE = 2048

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)
model.predict(train_features[:10])
# Out:
# array([[0.9307897 ],
#        [0.92776865],
#        [0.94075537],
#        [0.86907077],
#        [0.9494272 ],
#        [0.9600154 ],
#        [0.94334126],
#        [0.89996266],
#        [0.93008196],
#        [0.94593734]], dtype=float32)

# %%
model = make_model(metrics=Fbeta_loss_function)
model.fit(train_features, train_labels, epochs=10)
test_loss, test_acc = model.evaluate(test_features,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-437fc5c418e3> in <module>
#       1 model = make_model(metrics=Fbeta_loss_function)
# ----> 2 model.fit(train_features, train_labels, epochs=10)
#       3 test_loss, test_acc = model.evaluate(test_features,  test_labels, verbose=2)
#       4
#       5 print('\nTest accuracy:', test_acc)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
# ...

# %%
results = model.evaluate(train_features, train_labels, batch_size=BATCH_SIZE, verbose=0)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ac28a1b12335> in <module>
# ----> 1 results = model.evaluate(train_features, train_labels, batch_size=BATCH_SIZE, verbose=0)
#       2 print("Loss: {:0.4f}".format(results[0]))
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# ...

# %%
features=['TOP_FRAUDE',
 'TOP_FRAUDE_CARTE',
 'TOP_FRAUDE_VIREMENT',
 'TOP_E_RELEVE',
 'MESSAGERIE_WEB_ACTIVE',
 'NBJ_CNT_AGENCE_VENTE_6M',
 'TOT_CNX_WEB_WEEK_6M',
 'TOT_CNX_WEB_END_6M',
 'TOT_CCOMPTE_WEB_6M',
 'TOT_IMPRESSIONRIB_WEB_6M',
 'TOT_CCOMPTE_MBANQUE_6M',
 'TOT_MODIF_PARAM_CARTE_WEB_6M',
 'NB_JR_WEB_6M',
 'NB_CNXS_WEB_6M',
 'NB_JR_MBANQUE_6M',
 'NB_CNXS_MBANQUE_6M',
 'TOT_VIR_WEB_6M',
 'TX_PAIEMTNB_WEB_TOT_6M',
 'TX_PAIEMTMTT_WEB_TOT_6M',
 'NB_PAP_CLIQUEE_6M',
 'TAUX_LECTURE_PAP_6M',
 'NB_MAIL_LU_6M',
 'TAUX_LECTURE_EMAIL_6M',
 'anciennete',
 'top_affecte',
 'top_entretien_3M',
 'top_entretien_6M',
 'top_entretien_12M',
 'nb_mois_dernier_entretien',
 'csp_1',
 'note_mire',
 'note_FOpDebitrice',
 'note_FService',
 'MONETAIRE_BLOQUE_ECART_M6',
 'mt_remise_chq_M',
 'mt_remise_chq_M6',
 'nb_DAV',
 'nb_produit_Assurance',
 'nb_remise_chq_M',
 'nb_remise_chq_M6',
 'societaire_M',
 'top_ouv_prod_6M',
 'top_produit_Cartes',
 'top_produit_Credit',
 'Flag_bq_principale',
 'Client_2',
 'DUREE_CNX_WEB_TOT_6M',
 'DUREE_CNX_MOY_WEB_6M',
 'seg_nature_potentiel_GRAND PUBLIC',
 'type_residence_1_PROPRIETAIRE',
 'situ_fam_1_CELIBATAIRE',
 'Tranche_age_1_18-25',
 'Tranche_age_1_26-35',
 'Tranche_age_1_36-45',
 'Tranche_age_1_46-55',
 'Tranche_age_1_56-65',
 'Tranche_age_1_66-75',
 'Tranche_age_1_76-85',
 'Fidelite_calcule_NF',
 'profil_sans contact',
 'INDICSMS_SMS_NEUTRE',
 'INDICMAIL_MAIL_NEUTRE',
 'INDICMAIL_MAIL_OPTIN']
